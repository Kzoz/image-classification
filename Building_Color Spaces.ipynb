# %%
from PIL import Image
import imutils
import glob
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm
from skimage.color import rgb2gray
# %matplotlib inline
from scipy import ndimage

for infile in glob.glob("/content/drive/My Drive/PlantVillage/tomato_dataset/class_a/*.jpeg"):
    print("w")
    file, ext = os.path.splitext(infile)
    image = Image.open(infile)
    image = np.array(image)

    RGB_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    HLS_img = cv2.cvtColor(image, cv2.COLOR_BGR2HLS)
    #YCrCb_img = cv2.cvtColor(image, cv2.COLOR_BGR2YCR_CB)
    #h,l,s = cv2.split(HLS_img)
    #r,g,b = cv2.split(RGB_img)
    #HLG_img = cv2.merge((h,l,g))
    HLS_img.save('/content/drive/My Drive/PlantVillage/tomato_dataset/HLS_A.jpg', 'JPEG')

# %%
for infile in glob.glob("/content/drive/My Drive/PlantVillage/tomato_dataset/class_b/*.jpeg"):
    file, ext = os.path.splitext(infile)
    image = Image.open(infile)
    image = np.array(image)

    RGB_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    HLS_img = cv2.cvtColor(image, cv2.COLOR_BGR2HLS)
    YCrCb_img = cv2.cvtColor(image, cv2.COLOR_BGR2YCR_CB)
    h,l,s = cv2.split(HLS_img)
    r,g,b = cv2.split(RGB_img)
    HLG_img = cv2.merge((h,l,g))
    HLS_img.save(('/content/drive/My Drive/PlantVillage/tomato_dataset/HLS_B.jpg', 'JPEG')
